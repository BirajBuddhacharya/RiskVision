# %%
import os; os.chdir('../..') # changing to root directory of project
import pandas as pd 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pickle # saving trained model

# %%
# saving train data
X_train = pd.read_csv('data/model_training/diabetes/X_train.csv')
X_test = pd.read_csv('data/model_training/diabetes/X_test.csv')
y_train = pd.read_csv('data/model_training/diabetes/y_train.csv')
y_test = pd.read_csv('data/model_training/diabetes/y_test.csv')

# %%
# training model 
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# c:\Users\admin\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict_proba(X_test)[:, 1]
# Out:
# array([0.96031648, 0.16606703, 0.09638267, 0.6338    , 0.12703286,
#        0.03888763, 0.74437012, 0.85120565, 0.39880676, 0.36599841,
#        0.57494549, 0.95935294, 0.29366137, 0.18728141, 0.12688882,
#        0.16571971, 0.86121565, 0.02756   , 0.42719416, 0.2552206 ,
#        0.66217163, 0.42533997, 0.22614394, 0.06587312, 0.05237538,
#        0.36369747, 0.04774776, 0.90930924, 0.11409031, 0.145072  ,
#        0.46394475, 0.25309056, 0.09808036, 0.46152624, 0.10195834,
#        0.70938689, 0.4515724 , 0.08715824, 0.33497444, 0.73899423,
#        0.28796909, 0.22209399, 0.16292525, 0.82429576, 0.73552082,
#        0.00929659, 0.08605461, 0.20304581, 0.36203319, 0.30508803,
#        0.40340274, 0.19073887, 0.87300546, 0.4938157 , 0.13915781,
#        0.00285195, 0.06337607, 0.55168839, 0.28118192, 0.07400245,
#        0.71665053, 0.4637402 , 0.10987345, 0.72584886, 0.68645951,
#        0.90738962, 0.71570492, 0.14423836, 0.36213525, 0.11170716,
# ...

# %%
# model evaluation 
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.8246753246753247
# Precision: 0.7631578947368421
# Recall: 0.6170212765957447
# F1 Score: 0.6823529411764706

# %%
# saving model 
with open('models/diabetes/diabetes.pkl', 'wb') as fp: 
    pickle.dump(model,fp)
