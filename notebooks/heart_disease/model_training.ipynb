# %%
import os; os.chdir('../..') # changing to root directory of project
import pandas as pd 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pickle # saving trained model

# %%
# saving train data
X_train = pd.read_csv('data/model_training/heart_disease/X_train.csv')
X_test = pd.read_csv('data/model_training/heart_disease/X_test.csv')
y_train = pd.read_csv('data/model_training/heart_disease/y_train.csv')
y_test = pd.read_csv('data/model_training/heart_disease/y_test.csv')

# %%
# training model 
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# c:\Users\admin\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict_proba(X_test)[:, 1]
# Out:
# array([9.47069866e-01, 6.42875624e-01, 2.56723382e-03, 9.68135757e-01,
#        7.23857296e-03, 2.93943463e-02, 4.00655340e-02, 1.45413178e-02,
#        1.74925523e-02, 5.18570158e-01, 2.05070992e-01, 1.40209857e-03,
#        7.74384039e-01, 5.31146442e-01, 9.22478251e-01, 9.75873341e-01,
#        9.83849089e-01, 1.29649885e-03, 9.94749444e-01, 1.07692336e-01,
#        9.53695225e-01, 9.16955563e-01, 8.07277985e-01, 9.16955563e-01,
#        9.75873341e-01, 9.73587558e-01, 9.85652238e-01, 2.63025263e-01,
#        9.96240980e-01, 9.96667562e-01, 9.95699944e-01, 1.45413178e-02,
#        3.20350668e-02, 7.95617208e-01, 3.05910425e-01, 1.07176425e-03,
#        7.56665505e-01, 3.71579010e-01, 6.89621119e-01, 8.54059579e-01,
#        9.74241401e-01, 8.53256698e-01, 9.06849891e-01, 9.85902196e-01,
#        9.77456167e-01, 9.82560437e-01, 9.64545196e-01, 6.43267174e-01,
#        1.24821360e-03, 5.80572076e-01, 2.71437588e-01, 1.58679555e-02,
# ...

# %%
# model evaluation 
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.8829268292682927
# Precision: 0.8547008547008547
# Recall: 0.9345794392523364
# F1 Score: 0.8928571428571429

# %%
# saving model 
with open('models/heart_disease/heart_disease.pkl', 'wb') as fp: 
    pickle.dump(model,fp)
