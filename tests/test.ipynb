# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Separate dictionaries for each model
logistic_regression_metrics = {
    "Accuracy": 0.8341463414634146,
    "Precision": 0.8173913043478261,
    "F1-Score": 0.8468468468468469,
}

random_forest_metrics = {
    "Accuracy": 1.0,
    "Precision": 1.0,
    "F1-Score": 1.0,
}

svc_metrics = {
    "Accuracy": 0.8585365853658536,
    "Precision": 0.8545454545454545,
    "F1-Score": 0.8663594470046083,
}

# Create a DataFrame
metrics_df = pd.DataFrame({
    "Logistic Regression": logistic_regression_metrics,
    "Random Forest": random_forest_metrics,
    "SVC": svc_metrics
})

# Transpose the DataFrame to have models as rows
metrics_df = metrics_df.T

# Display the DataFrame
print(metrics_df)
# Out:
#                      Accuracy  Precision  F1-Score
# Logistic Regression  0.834146   0.817391  0.846847
# Random Forest        1.000000   1.000000  1.000000
# SVC                  0.858537   0.854545  0.866359

# %%
metrics_df.plot(kind='bar')
# Out:
# <Axes: >
